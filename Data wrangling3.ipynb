# %% [markdown]
# # DataFrame Slicing
# - ##### condition based
# - ##### label based
# - ##### int index based

# %%
import pandas as pd

# %%
df=pd.read_csv('f:/dataset/analysis/restaurant.csv')
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#condition based
df[df.time=='Dinner']
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
df[(df.time=='Dinner') & (df.gender=='Female')]
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# 32        15.06  3.00  Female     No   Sat  Dinner     2
# 33        20.69  2.45  Female     No   Sat  Dinner     4
# 37        16.93  3.07  Female     No   Sat  Dinner     3
# 51        10.29  2.60  Female     No   Sun  Dinner     2
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 57        26.41  1.50  Female     No   Sat  Dinner     2
# ...

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#df[(df.day=='Sun')|(df.day=='Sat')]
df[df.day.isin(['Sun','Sat'])]
# Out:
#      total_bill   tip  gender smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]

# %%
#df[(df.total_bill>=30) & (df.total_bill<=40)]
df[df.total_bill.between(30,40)]
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 39        31.27  5.00    Male     No   Sat  Dinner     3
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 83        32.68  5.00    Male    Yes  Thur   Lunch     2
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 112       38.07  4.00    Male     No   Sun  Dinner     3
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 167       31.71  4.50    Male     No   Sun  Dinner     4
# 173       31.85  3.18    Male    Yes   Sun  Dinner     2
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2
# 179       34.63  3.55    Male    Yes   Sun  Dinner     2
# ...

# %%
#label(named) slicing
#df.loc[startRowIndex:endRowIndex:step,startCol_Label:endCol_label:step]
#Note-->start,end both are inclusive
df.loc[0:4:1,'total_bill':'gender':1]
# Out:
#    total_bill   tip  gender
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#int index(position) slicing
#df.iloc[startRowInt_Index:endRowInt_Index:step,startColInt_Index:endColInt_Index:step]
#Note-->start is inclusive but end is exclusive
df.iloc[0:4:1,0:2:1]
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31

# %%
df.iloc[0:4:1,0:2:1]
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31

# %%
df.iloc[0:4:1,0:6:1]
# Out:
#    total_bill   tip  gender smoker  day    time
# 0       16.99  1.01  Female     No  Sun  Dinner
# 1       10.34  1.66    Male     No  Sun  Dinner
# 2       21.01  3.50    Male     No  Sun  Dinner
# 3       23.68  3.31    Male     No  Sun  Dinner

# %%
df.iloc[0:4:1,0:-1:1]
# Out:
#    total_bill   tip  gender smoker  day    time
# 0       16.99  1.01  Female     No  Sun  Dinner
# 1       10.34  1.66    Male     No  Sun  Dinner
# 2       21.01  3.50    Male     No  Sun  Dinner
# 3       23.68  3.31    Male     No  Sun  Dinner

# %%
df.iloc[:10,1:-1]
# Out:
#     tip  gender smoker  day    time
# 0  1.01  Female     No  Sun  Dinner
# 1  1.66    Male     No  Sun  Dinner
# 2  3.50    Male     No  Sun  Dinner
# 3  3.31    Male     No  Sun  Dinner
# 4  3.61  Female     No  Sun  Dinner
# 5  4.71    Male     No  Sun  Dinner
# 6  2.00    Male     No  Sun  Dinner
# 7  3.12    Male     No  Sun  Dinner
# 8  1.96    Male     No  Sun  Dinner
# 9  3.23    Male     No  Sun  Dinner

# %%
df.iloc[100:,2:]
# Out:
#      gender smoker   day    time  size
# 100  Female    Yes   Fri  Dinner     2
# 101  Female    Yes   Fri  Dinner     2
# 102  Female    Yes   Sat  Dinner     3
# 103  Female    Yes   Sat  Dinner     2
# 104  Female     No   Sat  Dinner     2
# ..      ...    ...   ...     ...   ...
# 239    Male     No   Sat  Dinner     3
# 240  Female    Yes   Sat  Dinner     2
# 241    Male    Yes   Sat  Dinner     2
# 242    Male     No   Sat  Dinner     2
# 243  Female     No  Thur  Dinner     2
#
# [144 rows x 5 columns]

# %%
#other cases with conditional slicing
df=pd.read_csv('f:/dataset/analysis/movies.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating   category  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[df.actors_list.str.contains('amir',case=False)]
# Out:
#      star_rating                              title content_rating   category  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 239          8.1      Elite Squad: The Enemy Within        UNRATED     Action
# 261          8.1                        Elite Squad              R     Action
# 566          7.8                    Boyz n the Hood              R      Crime
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# ...

# %%
df=pd.read_csv('f:/dataset/analysis/weather_data.txt')
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df[df.temperature.isnull()]
# Out:
#         day  temperature  windspeed  event
# 1  1/4/2017          NaN        9.0  Sunny
# 3  1/6/2017          NaN        7.0    NaN
# 5  1/8/2017          NaN        NaN  Sunny
# 6  1/9/2017          NaN        NaN    NaN

# %%
df[df.temperature.notnull()]
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 2   1/5/2017         28.0        NaN    Snow
# 4   1/7/2017         32.0        NaN    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %% [markdown]
# # EDA(Exploratory Data Analysis)
# - It provides structural information of data.
# - It identifies relationship b/w cols.
# - It gives you main characterstics(summary) of data.
# - Data distribution in each col.
# - Data Visualization.

# %%
df=pd.read_csv('f:/dataset/analysis/restaurant.csv')
#structural information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   gender      244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#Main chars(summary)
df.describe() #for numeric cols only
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(include='all')
# Out:
#         total_bill         tip gender smoker  day    time        size
# count   244.000000  244.000000    244    244  244     244  244.000000
# unique         NaN         NaN      2      2    4       2         NaN
# top            NaN         NaN   Male     No  Sat  Dinner         NaN
# freq           NaN         NaN    157    151   87     176         NaN
# mean     19.785943    2.998279    NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638    NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000    NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000    NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000    NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500    NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000    NaN    NaN  NaN     NaN    6.000000

# %%
#relationship b/w cols
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#frequency table b/w 2 categorical cols
pd.crosstab(index=df.gender,columns=df.time,margins=True)
# Out:
# time    Dinner  Lunch  All
# gender
# Female      52     35   87
# Male       124     33  157
# All        176     68  244

# %%
52/176
# Out:
# 0.29545454545454547

# %%
124/176
# Out:
# 0.7045454545454546
